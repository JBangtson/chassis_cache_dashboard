# %%
#Gets Data
def query_database(query):
    """
    Function to query the carbitrage database and return the results.
    
    Args:
        query (str): The SQL query to execute.
    
    Returns:
        list: A list of dictionaries containing the query results.
    """
    import sqlite3

    db_path = r'F:\Portfolio_Website\Portfolio_Website\data\carbitrage.db'  # Corrected path with raw string
    connection = sqlite3.connect(db_path)
    cursor = connection.cursor()
    
    try:
        cursor.execute(query)
        columns = [description[0] for description in cursor.description]
        results = cursor.fetchall()
        data = [dict(zip(columns, row)) for row in results]
    except sqlite3.Error as e:
        print(f"Database error: {e}")
        data = []
    finally:
        cursor.close()
        connection.close()
    
    return data  # Return data as a list of dictionaries

def create_view(view_name, query):
    """
    Function to create a view in the carbitrage database.
    
    Args:
        view_name (str): The name of the view to create.
        query (str): The SQL query to define the view.
    """
    import sqlite3

    db_path = r'F:\Portfolio_Website\Portfolio_Website\data\carbitrage.db'  # Corrected path with raw string
    connection = sqlite3.connect(db_path)
    cursor = connection.cursor()
    
    try:
        cursor.execute(f"DROP VIEW IF EXISTS {view_name}")
        cursor.execute(f"CREATE VIEW {view_name} AS {query}")
        connection.commit()
        print(f"View {view_name} created successfully.")
    except sqlite3.Error as e:
        print(f"Database error: {e}")
    finally:
        cursor.close()
        connection.close()




def create_table(table_name, columns):
    """
    Function to create a table in the carbitrage database.
    
    Args:
        table_name (str): The name of the table to create.
        columns (str): The SQL column definitions for the table.
    """
    import sqlite3

    db_path = r'F:\Portfolio_Website\Portfolio_Website\data\carbitrage.db'  # Corrected path with raw string
    connection = sqlite3.connect(db_path)
    cursor = connection.cursor()
    
    try:
        cursor.execute(f"DROP TABLE IF EXISTS {table_name}")
        cursor.execute(f"CREATE TABLE {table_name} AS {columns}")
        connection.commit()
        print(f"Table {table_name} created successfully.")
    except sqlite3.Error as e:
        print(f"Database error: {e}")
    finally:
        cursor.close()
        connection.close()

# %%
year_avgprice_table_query = """
WITH year AS (
    SELECT year
    FROM carbitrage_table
    GROUP BY year
),
lessthan50k AS (
    SELECT year, ROUND(AVG(price), 2) as avg_lessthan50k
    FROM carbitrage_table
    WHERE odometer < 50000
    GROUP BY year
),
fiftyTo75k AS (
    SELECT year, ROUND(AVG(price), 2) as avg_fiftyTo75k
    FROM carbitrage_table
    WHERE odometer BETWEEN 50000 AND 74999
    GROUP BY year
),
seventy5To100k AS (
    SELECT year, ROUND(AVG(price), 2) as avg_seventy5To100k
    FROM carbitrage_table
    WHERE odometer BETWEEN 75000 AND 99999
    GROUP BY year
),
over100k AS (
    SELECT year, ROUND(AVG(price), 2) as avg_over100k
    FROM carbitrage_table
    WHERE odometer >= 100000
    GROUP BY year
)
SELECT year.year, lessthan50k.avg_lessthan50k, fiftyTo75k.avg_fiftyTo75k, seventy5To100k.avg_seventy5To100k, over100k.avg_over100k
FROM year
JOIN lessthan50k ON year.year = lessthan50k.year
JOIN fiftyTo75k ON year.year = fiftyTo75k.year
JOIN seventy5To100k ON year.year = seventy5To100k.year
JOIN over100k ON year.year = over100k.year;
"""
print(query_database(year_avgprice_table_query))
# Out:
# [{'year': '1974', 'avg_lessthan50k': 13586.23, 'avg_fiftyTo75k': 13967.0, 'avg_seventy5To100k': 13429.58, 'avg_over100k': 13605.81}, {'year': '1975', 'avg_lessthan50k': 13477.27, 'avg_fiftyTo75k': 13995.72, 'avg_seventy5To100k': 13227.25, 'avg_over100k': 13487.28}, {'year': '1976', 'avg_lessthan50k': 12746.03, 'avg_fiftyTo75k': 12417.72, 'avg_seventy5To100k': 11245.67, 'avg_over100k': 12345.88}, {'year': '1977', 'avg_lessthan50k': 11467.07, 'avg_fiftyTo75k': 12741.93, 'avg_seventy5To100k': 12215.59, 'avg_over100k': 11924.89}, {'year': '1978', 'avg_lessthan50k': 12375.86, 'avg_fiftyTo75k': 13797.18, 'avg_seventy5To100k': 12068.38, 'avg_over100k': 12624.37}, {'year': '1979', 'avg_lessthan50k': 11924.94, 'avg_fiftyTo75k': 14503.15, 'avg_seventy5To100k': 12741.45, 'avg_over100k': 12707.65}, {'year': '1980', 'avg_lessthan50k': 10903.42, 'avg_fiftyTo75k': 10515.57, 'avg_seventy5To100k': 10650.7, 'avg_over100k': 10675.44}, {'year': '1981', 'avg_lessthan50k': 10462.41, 'avg_fiftyTo75k': 10455.14, 'avg_seventy5To100k': 11605.57, 'avg_over100k': 10674.78}, {'year': '1982', 'avg_lessthan50k': 10891.99, 'avg_fiftyTo75k': 12894.69, 'avg_seventy5To100k': 11056.99, 'avg_over100k': 11258.2}, {'year': '1983', 'avg_lessthan50k': 10845.96, 'avg_fiftyTo75k': 11881.17, 'avg_seventy5To100k': 9933.08, 'avg_over100k': 10840.83}, {'year': '1984', 'avg_lessthan50k': 10077.63, 'avg_fiftyTo75k': 10393.87, 'avg_seventy5To100k': 9894.81, 'avg_over100k': 10102.25}, {'year': '1985', 'avg_lessthan50k': 10538.22, 'avg_fiftyTo75k': 11177.6, 'avg_seventy5To100k': 9321.12, 'avg_over100k': 10385.54}, {'year': '1986', 'avg_lessthan50k': 10229.58, 'avg_fiftyTo75k': 12338.98, 'avg_seventy5To100k': 10545.21, 'avg_over100k': 10642.72}, {'year': '1987', 'avg_lessthan50k': 10146.59, 'avg_fiftyTo75k': 12065.03, 'avg_seventy5To100k': 11304.77, 'avg_over100k': 10612.42}, {'year': '1988', 'avg_lessthan50k': 9127.59, 'avg_fiftyTo75k': 10770.57, 'avg_seventy5To100k': 8915.24, 'avg_over100k': 9269.76}, {'year': '1989', 'avg_lessthan50k': 8536.73, 'avg_fiftyTo75k': 12736.44, 'avg_seventy5To100k': 9983.25, 'avg_over100k': 9236.06}, {'year': '1990', 'avg_lessthan50k': 8481.62, 'avg_fiftyTo75k': 11804.57, 'avg_seventy5To100k': 11325.44, 'avg_over100k': 9270.98}, {'year': '1991', 'avg_lessthan50k': 8454.73, 'avg_fiftyTo75k': 10352.59, 'avg_seventy5To100k': 9883.18, 'avg_over100k': 8839.11}, {'year': '1992', 'avg_lessthan50k': 7792.23, 'avg_fiftyTo75k': 10588.98, 'avg_seventy5To100k': 9436.49, 'avg_over100k': 8199.66}, {'year': '1993', 'avg_lessthan50k': 7757.39, 'avg_fiftyTo75k': 11813.34, 'avg_seventy5To100k': 10198.37, 'avg_over100k': 8330.26}, {'year': '1994', 'avg_lessthan50k': 7527.4, 'avg_fiftyTo75k': 11135.16, 'avg_seventy5To100k': 9402.06, 'avg_over100k': 7990.28}, {'year': '1995', 'avg_lessthan50k': 7404.16, 'avg_fiftyTo75k': 11938.22, 'avg_seventy5To100k': 10049.82, 'avg_over100k': 7986.45}, {'year': '1996', 'avg_lessthan50k': 7180.25, 'avg_fiftyTo75k': 10938.33, 'avg_seventy5To100k': 9850.27, 'avg_over100k': 7684.03}, {'year': '1997', 'avg_lessthan50k': 6750.06, 'avg_fiftyTo75k': 11521.13, 'avg_seventy5To100k': 8897.52, 'avg_over100k': 7173.89}, {'year': '1998', 'avg_lessthan50k': 5872.72, 'avg_fiftyTo75k': 11667.02, 'avg_seventy5To100k': 8614.07, 'avg_over100k': 6400.66}, {'year': '1999', 'avg_lessthan50k': 6373.27, 'avg_fiftyTo75k': 11962.2, 'avg_seventy5To100k': 9114.93, 'avg_over100k': 6894.75}, {'year': '2000', 'avg_lessthan50k': 6253.95, 'avg_fiftyTo75k': 10662.53, 'avg_seventy5To100k': 9432.29, 'avg_over100k': 6717.58}, {'year': '2001', 'avg_lessthan50k': 6138.67, 'avg_fiftyTo75k': 11383.91, 'avg_seventy5To100k': 8777.47, 'avg_over100k': 6576.49}, {'year': '2002', 'avg_lessthan50k': 5999.75, 'avg_fiftyTo75k': 11519.33, 'avg_seventy5To100k': 8899.25, 'avg_over100k': 6489.38}, {'year': '2003', 'avg_lessthan50k': 5994.06, 'avg_fiftyTo75k': 11512.89, 'avg_seventy5To100k': 8661.3, 'avg_over100k': 6457.89}, {'year': '2004', 'avg_lessthan50k': 6004.42, 'avg_fiftyTo75k': 1 ...

# %%
import json

# Sample data from test_query
data = query_database(year_avgprice_table_query)

# Convert the data to JSON format
data_json = json.dumps(data, indent=4)

# Print the JSON data
print(data_json)
# Out:
# [
#     {
#         "year": "1974",
#         "avg_lessthan50k": 13586.23,
#         "avg_fiftyTo75k": 13967.0,
#         "avg_seventy5To100k": 13429.58,
#         "avg_over100k": 13605.81
#     },
#     {
#         "year": "1975",
#         "avg_lessthan50k": 13477.27,
#         "avg_fiftyTo75k": 13995.72,
#         "avg_seventy5To100k": 13227.25,
#         "avg_over100k": 13487.28
#     },
#     {
#         "year": "1976",
#         "avg_lessthan50k": 12746.03,
#         "avg_fiftyTo75k": 12417.72,
#         "avg_seventy5To100k": 11245.67,
#         "avg_over100k": 12345.88
#     },
#     {
#         "year": "1977",
#         "avg_lessthan50k": 11467.07,
#         "avg_fiftyTo75k": 12741.93,
#         "avg_seventy5To100k": 12215.59,
#         "avg_over100k": 11924.89
#     },
#     {
#         "year": "1978",
#         "avg_lessthan50k": 12375.86,
#         "avg_fiftyTo75k": 13797.18,
#         "avg_seventy5To100k": 12068.38,
#         "avg_over100k": 12624.37
#     },
#     {
#         "year": "1979",
#         "avg_lessthan50k": 11924.94,
#         "avg_fiftyTo75k": 14503.15,
#         "avg_seventy5To100k": 12741.45,
#         "avg_over100k": 12707.65
#     },
#     {
#         "year": "1980",
#         "avg_lessthan50k": 10903.42,
#         "avg_seventy5To100k": 10948.53,
#         "avg_over100k": 8478.94
#     },
#     {
#         "year": "2012",
#         "avg_lessthan50k": 8280.04,
#         "avg_fiftyTo75k": 13301.74,
#         "avg_seventy5To100k": 10781.78,
#         "avg_over100k": 8882.9
#     },
#     {
#         "year": "2013",
#         "avg_lessthan50k": 9052.87,
#         "avg_fiftyTo75k": 13876.83,
#         "avg_seventy5To100k": 11383.34,
#         "avg_over100k": 9762.37
#     },
#     {
#         "year": "2014",
#         "avg_lessthan50k": 10335.68,
#         "avg_fiftyTo75k": 15595.56,
#         "avg_seventy5To100k": 12622.77,
#         "avg_over100k": 11215.79
#     },
#     {
#         "year": "2015",
#         "avg_lessthan50k": 12349.31,
#         "avg_fiftyTo75k": 16928.4,
#         "avg_seventy5To100k": 14379.79,
#         "avg_over100k": 13340.13
#     },
#     {
#         "year": "2016",
#         "avg_lessthan50k": 14025.79,
#         "avg_fiftyTo75k": 18535.86,
#         "avg_seventy5To100k": 15858.95,
#         "avg_over100k": 15192.16
#     },
#     {
#         "year": "2017",
#         "avg_lessthan50k": 16780.85,
#         "avg_fiftyTo75k": 19666.57,
#         "avg_seventy5To100k": 17064.04,
#         "avg_over100k": 17452.72
#     },
#     {
#         "year": "2018",
#         "avg_lessthan50k": 20244.89,
#         "avg_fiftyTo75k": 21464.43,
#         "avg_seventy5To100k": 19216.62,
#         "avg_over100k": 20338.77
#     },
#     {
#         "year": "2019",
#         "avg_lessthan50k": 23845.07,
#         "avg_fiftyTo75k": 22843.36,
#         "avg_seventy5To100k": 21035.91,
#         "avg_over100k": 23063.66
#     },
#     {
#         "year": "2020",
#         "avg_lessthan50k": 27566.61,
#         "avg_fiftyTo75k": 25281.74,
#         "avg_seventy5To100k": 24539.78,
#         "avg_over100k": 26544.66
#     },
#     {
#         "year": "2021",
#         "avg_lessthan50k": 31572.96,
#         "avg_fiftyTo75k": 28700.98,
#         "avg_seventy5To100k": 30058.5,
#         "avg_over100k": 30824.85
#     },
#     {
#         "year": "2022",
#         "avg_lessthan50k": 35146.17,
#         "avg_fiftyTo75k": 33428.65,
#         "avg_seventy5To100k": 35783.52,
#         "avg_over100k": 35067.57
#     },
#     {
#         "year": "2023",
#         "avg_lessthan50k": 36489.51,
#         "avg_fiftyTo75k": 37803.77,
#         "avg_seventy5To100k": 39657.53,
#         "avg_over100k": 37155.09
#     },
#     {
#         "year": "2024",
#         "avg_lessthan50k": 33276.53,
#         "avg_fiftyTo75k": 38554.85,
#         "avg_seventy5To100k": 35481.22,
#         "avg_over100k": 35137.87
#     },
#     {
#         "year": "2025",
#         "avg_lessthan50k": 15087.79,
#         "avg_fiftyTo75k": 15619.4,
#         "avg_seventy5To100k": 10490.53,
#         "avg_over100k": 15143.01
#     }
# ]

# %% [markdown]
# # View for Average Price by Year for <50, 50-75k, etc.

# %%
create_view("year_avgprice_view","""
WITH year AS (
    SELECT year
    FROM carbitrage_table
    GROUP BY year
),
lessthan50k AS (
    SELECT year, ROUND(AVG(price), 2) as avg_lessthan50k
    FROM carbitrage_table
    WHERE odometer < 50000
    GROUP BY year
),
fiftyTo75k AS (
    SELECT year, ROUND(AVG(price), 2) as avg_fiftyTo75k
    FROM carbitrage_table
    WHERE odometer BETWEEN 50000 AND 74999
    GROUP BY year
),
seventy5To100k AS (
    SELECT year, ROUND(AVG(price), 2) as avg_seventy5To100k
    FROM carbitrage_table
    WHERE odometer BETWEEN 75000 AND 99999
    GROUP BY year
),
over100k AS (
    SELECT year, ROUND(AVG(price), 2) as avg_over100k
    FROM carbitrage_table
    WHERE odometer >= 100000
    GROUP BY year
)
SELECT year.year, lessthan50k.avg_lessthan50k, fiftyTo75k.avg_fiftyTo75k, seventy5To100k.avg_seventy5To100k, over100k.avg_over100k
FROM year
JOIN lessthan50k ON year.year = lessthan50k.year
JOIN fiftyTo75k ON year.year = fiftyTo75k.year
JOIN seventy5To100k ON year.year = seventy5To100k.year
JOIN over100k ON year.year = over100k.year;
""")
# Out:
# View year_avgprice_view created successfully.

# %%
create_table("year_avgprice_table", """
WITH year AS (
    SELECT year
    FROM carbitrage_table
    GROUP BY year
),
lessthan50k AS (
    SELECT year, ROUND(AVG(price), 2) as avg_lessthan50k
    FROM carbitrage_table
    WHERE odometer < 50000 AND price BETWEEN 1000 AND 79999
    GROUP BY year
),
fiftyTo75k AS (
    SELECT year, ROUND(AVG(price), 2) as avg_fiftyTo75k
    FROM carbitrage_table
    WHERE odometer BETWEEN 50000 AND 74999 AND price BETWEEN 1000 AND 79999
    GROUP BY year
),
seventy5To100k AS (
    SELECT year, ROUND(AVG(price), 2) as avg_seventy5To100k
    FROM carbitrage_table
    WHERE odometer BETWEEN 75000 AND 99999 AND price BETWEEN 1000 AND 79999
    GROUP BY year
),
over100k AS (
    SELECT year, ROUND(AVG(price), 2) as avg_over100k
    FROM carbitrage_table
    WHERE odometer >= 100000 AND price BETWEEN 1000 AND 79999
    GROUP BY year
)
SELECT year.year, lessthan50k.avg_lessthan50k, fiftyTo75k.avg_fiftyTo75k, seventy5To100k.avg_seventy5To100k, over100k.avg_over100k
FROM year
LEFT JOIN lessthan50k ON year.year = lessthan50k.year
LEFT JOIN fiftyTo75k ON year.year = fiftyTo75k.year
LEFT JOIN seventy5To100k ON year.year = seventy5To100k.year
LEFT JOIN over100k ON year.year = over100k.year;
""")
# Out:
# Table year_avgprice_table created successfully.

# %%
select_all_from_view_query = """
SELECT *
FROM year_avgprice_view;
"""

# Execute the query and fetch the results
data_from_view = query_database(select_all_from_view_query)

# Convert the data to JSON format
data_from_view_json = json.dumps(data_from_view, indent=4)

# Print the JSON data
print(data_from_view_json)
# Out:
# [
#     {
#         "year": "1974",
#         "avg_lessthan50k": 13586.23,
#         "avg_fiftyTo75k": 13967.0,
#         "avg_seventy5To100k": 13429.58,
#         "avg_over100k": 13605.81
#     },
#     {
#         "year": "1975",
#         "avg_lessthan50k": 13477.27,
#         "avg_fiftyTo75k": 13995.72,
#         "avg_seventy5To100k": 13227.25,
#         "avg_over100k": 13487.28
#     },
#     {
#         "year": "1976",
#         "avg_lessthan50k": 12746.03,
#         "avg_fiftyTo75k": 12417.72,
#         "avg_seventy5To100k": 11245.67,
#         "avg_over100k": 12345.88
#     },
#     {
#         "year": "1977",
#         "avg_lessthan50k": 11467.07,
#         "avg_fiftyTo75k": 12741.93,
#         "avg_seventy5To100k": 12215.59,
#         "avg_fiftyTo75k": 11813.34,
#         "avg_seventy5To100k": 10198.37,
#         "avg_over100k": 8330.26
#     },
#     {
#         "year": "1994",
#         "avg_lessthan50k": 7527.4,
#         "avg_fiftyTo75k": 11135.16,
#         "avg_seventy5To100k": 9402.06,
#         "avg_over100k": 7990.28
#     },
#     {
#         "year": "1995",
#         "avg_lessthan50k": 7404.16,
#         "avg_fiftyTo75k": 11938.22,
#         "avg_seventy5To100k": 10049.82,
#         "avg_over100k": 7986.45
#     },
#     {
#         "year": "1996",
#         "avg_lessthan50k": 7180.25,
#         "avg_fiftyTo75k": 10938.33,
#         "avg_seventy5To100k": 9850.27,
#         "avg_over100k": 7684.03
#     },
#     {
#         "year": "1997",
#         "avg_lessthan50k": 6750.06,
#         "avg_fiftyTo75k": 11521.13,
#         "avg_seventy5To100k": 8897.52,
#         "avg_over100k": 7173.89
#     },
#     {
#         "year": "1998",
#         "avg_lessthan50k": 5872.72,
#         "avg_fiftyTo75k": 11667.02,
#         "avg_seventy5To100k": 8614.07,
#         "avg_over100k": 6400.66
#     },
#     {
#         "year": "1999",
#         "avg_lessthan50k": 6373.27,
#         "avg_fiftyTo75k": 11962.2,
#         "avg_seventy5To100k": 9114.93,
#         "avg_over100k": 6894.75
#     },
#     {
#         "year": "2000",
#         "avg_lessthan50k": 6253.95,
#         "avg_fiftyTo75k": 10662.53,
#         "avg_seventy5To100k": 9432.29,
#         "avg_over100k": 6717.58
#     },
#     {
#         "year": "2001",
#         "avg_lessthan50k": 6138.67,
#         "avg_fiftyTo75k": 11383.91,
#         "avg_seventy5To100k": 8777.47,
#         "avg_over100k": 6576.49
#     },
#     {
#         "year": "2002",
#         "avg_lessthan50k": 5999.75,
#         "avg_fiftyTo75k": 11519.33,
#         "avg_seventy5To100k": 8899.25,
#         "avg_over100k": 6489.38
#     },
#     {
#         "year": "2003",
#         "avg_lessthan50k": 5994.06,
#         "avg_fiftyTo75k": 11512.89,
#         "avg_seventy5To100k": 8661.3,
#         "avg_over100k": 6457.89
#     },
#     {
#         "year": "2004",
#         "avg_lessthan50k": 6004.42,
#         "avg_fiftyTo75k": 12141.31,
#         "avg_seventy5To100k": 9140.63,
#         "avg_over100k": 6523.73
#     },
#     {
#         "year": "2005",
#         "avg_lessthan50k": 6054.88,
#         "avg_fiftyTo75k": 11247.46,
#         "avg_seventy5To100k": 9474.19,
#         "avg_over100k": 6573.32
#     },
#     {
#         "year": "2006",
#         "avg_lessthan50k": 6342.41,
#         "avg_fiftyTo75k": 13227.94,
#         "avg_seventy5To100k": 9585.12,
#         "avg_over100k": 6902.19
#     },
#     {
#         "year": "2007",
#         "avg_lessthan50k": 6416.13,
#         "avg_fiftyTo75k": 12492.24,
#         "avg_seventy5To100k": 9173.38,
#         "avg_over100k": 6884.63
#     },
#     {
#         "year": "2008",
#         "avg_lessthan50k": 6624.36,
#         "avg_fiftyTo75k": 12965.04,
#         "avg_seventy5To100k": 9558.33,
#         "avg_over100k": 7151.5
#         "avg_seventy5To100k": 35481.22,
#         "avg_over100k": 35137.87
#     },
#     {
#         "year": "2025",
#         "avg_lessthan50k": 15087.79,
#         "avg_fiftyTo75k": 15619.4,
#         "avg_seventy5To100k": 10490.53,
#         "avg_over100k": 15143.01
#     }
# ]

# %%
import json

# Sample data from test_query
data = query_database(year_avgprice_table_query)

# Convert the data to JSON format
data_json = json.dumps(data, indent=4)

# Print the JSON data
print(data_json)
# Out:
# [
#     {
#         "year": "1974",
#         "avg_lessthan50k": 13586.23,
#         "avg_fiftyTo75k": 13967.0,
#         "avg_seventy5To100k": 13429.58,
#         "avg_over100k": 13605.81
#     },
#     {
#         "year": "1975",
#         "avg_lessthan50k": 13477.27,
#         "avg_fiftyTo75k": 13995.72,
#         "avg_seventy5To100k": 13227.25,
#         "avg_over100k": 13487.28
#     },
#     {
#         "year": "1976",
#         "avg_lessthan50k": 12746.03,
#         "avg_fiftyTo75k": 12417.72,
#         "avg_seventy5To100k": 11245.67,
#         "avg_over100k": 12345.88
#     },
#     {
#         "year": "1977",
#         "avg_lessthan50k": 11467.07,
#         "avg_fiftyTo75k": 12741.93,
#         "avg_seventy5To100k": 12215.59,
#         "avg_over100k": 11924.89
#     },
#     {
#         "year": "1978",
#         "avg_lessthan50k": 12375.86,
#         "avg_fiftyTo75k": 13797.18,
#         "avg_seventy5To100k": 12068.38,
#         "avg_over100k": 12624.37
#     },
#     {
#         "year": "1979",
#         "avg_lessthan50k": 11924.94,
#         "avg_fiftyTo75k": 14503.15,
#         "avg_seventy5To100k": 12741.45,
#         "avg_over100k": 12707.65
#     },
#     {
#         "year": "1980",
#         "avg_lessthan50k": 10903.42,
#         "avg_fiftyTo75k": 10515.57,
#         "avg_seventy5To100k": 10650.7,
#         "avg_over100k": 10675.44
#     },
#     {
#         "year": "1981",
#         "avg_lessthan50k": 10462.41,
#         "avg_fiftyTo75k": 10455.14,
#         "avg_seventy5To100k": 11605.57,
#         "avg_over100k": 10674.78
#     },
#     {
#         "year": "1982",
#         "avg_lessthan50k": 10891.99,
#         "avg_fiftyTo75k": 12894.69,
#         "avg_seventy5To100k": 11056.99,
#         "avg_over100k": 11258.2
#     },
#     {
#         "year": "1983",
#         "avg_lessthan50k": 10845.96,
#         "avg_fiftyTo75k": 11881.17,
#         "avg_seventy5To100k": 9933.08,
#         "avg_over100k": 10840.83
#     },
#     {
#         "year": "1984",
#         "avg_lessthan50k": 10077.63,
#         "avg_fiftyTo75k": 10393.87,
#         "avg_seventy5To100k": 9894.81,
#         "avg_over100k": 10102.25
#     },
#     {
#         "year": "1985",
#         "avg_lessthan50k": 10538.22,
#         "avg_fiftyTo75k": 11177.6,
#         "avg_seventy5To100k": 9321.12,
#         "avg_over100k": 10385.54
#     },
#     {
#         "year": "1986",
#         "avg_lessthan50k": 10229.58,
#         "avg_fiftyTo75k": 12338.98,
#         "avg_seventy5To100k": 10545.21,
#         "avg_over100k": 10642.72
#     },
#     {
#         "year": "1987",
#         "avg_lessthan50k": 10146.59,
#         "avg_fiftyTo75k": 12065.03,
#         "avg_seventy5To100k": 11304.77,
#         "avg_over100k": 10612.42
#     },
#     {
#         "year": "1988",
#         "avg_lessthan50k": 9127.59,
#         "avg_fiftyTo75k": 10770.57,
#         "avg_seventy5To100k": 8915.24,
#         "avg_over100k": 9269.76
#     },
#     {
#         "year": "1989",
#         "avg_lessthan50k": 8536.73,
#         "avg_fiftyTo75k": 12736.44,
#         "avg_seventy5To100k": 9983.25,
#         "avg_over100k": 9236.06
#     },
#     {
#         "year": "1990",
#         "avg_lessthan50k": 8481.62,
#         "avg_fiftyTo75k": 11804.57,
#         "avg_seventy5To100k": 11325.44,
#         "avg_over100k": 9270.98
#     },
#     {
#         "year": "1991",
#         "avg_lessthan50k": 8454.73,
#         "avg_fiftyTo75k": 10352.59,
#         "avg_seventy5To100k": 9883.18,
#         "avg_over100k": 8839.11
#     },
#     {
#         "year": "1992",
#         "avg_lessthan50k": 7792.23,
#         "avg_fiftyTo75k": 10588.98,
#         "avg_seventy5To100k": 9436.49,
#         "avg_over100k": 8199.66
#     },
#     {
#         "year": "1993",
#         "avg_lessthan50k": 7757.39,
#         "avg_fiftyTo75k": 11813.34,
#         "avg_seventy5To100k": 10198.37,
#         "avg_over100k": 8330.26
#     },
#     {
#         "year": "1994",
#         "avg_lessthan50k": 7527.4,
#         "avg_fiftyTo75k": 11135.16,
#         "avg_seventy5To100k": 9402.06,
#         "avg_over100k": 7990.28
#     },
#     {
#         "year": "1995",
#         "avg_lessthan50k": 7404.16,
#         "avg_fiftyTo75k": 11938.22,
#         "avg_seventy5To100k": 10049.82,
#         "avg_over100k": 7986.45
#     },
#     {
#         "year": "1996",
#         "avg_lessthan50k": 7180.25,
#         "avg_fiftyTo75k": 10938.33,
#         "avg_seventy5To100k": 9850.27,
#         "avg_over100k": 7684.03
#     },
#     {
#         "year": "1997",
#         "avg_lessthan50k": 6750.06,
#         "avg_fiftyTo75k": 11521.13,
#         "avg_seventy5To100k": 8897.52,
#         "avg_over100k": 7173.89
#     },
#     {
#         "year": "1998",
#         "avg_lessthan50k": 5872.72,
#         "avg_fiftyTo75k": 11667.02,
#         "avg_seventy5To100k": 8614.07,
#         "avg_over100k": 6400.66
#     },
#     {
#         "year": "1999",
#         "avg_lessthan50k": 6373.27,
#         "avg_fiftyTo75k": 11962.2,
#         "avg_seventy5To100k": 9114.93,
#         "avg_over100k": 6894.75
#     },
#     {
#         "year": "2000",
#         "avg_lessthan50k": 6253.95,
#         "avg_fiftyTo75k": 10662.53,
#         "avg_seventy5To100k": 9432.29,
#         "avg_over100k": 6717.58
#     },
#     {
#         "year": "2001",
#         "avg_lessthan50k": 6138.67,
#         "avg_fiftyTo75k": 11383.91,
#         "avg_seventy5To100k": 8777.47,
#         "avg_over100k": 6576.49
#     },
#     {
#         "year": "2002",
#         "avg_lessthan50k": 5999.75,
#         "avg_fiftyTo75k": 11519.33,
#         "avg_seventy5To100k": 8899.25,
#         "avg_over100k": 6489.38
#     },
#     {
#         "year": "2003",
#         "avg_lessthan50k": 5994.06,
#         "avg_fiftyTo75k": 11512.89,
#         "avg_seventy5To100k": 8661.3,
#         "avg_over100k": 6457.89
#     },
#     {
#         "year": "2004",
#         "avg_lessthan50k": 6004.42,
#         "avg_fiftyTo75k": 12141.31,
#         "avg_seventy5To100k": 9140.63,
#         "avg_over100k": 6523.73
#     },
#     {
#         "year": "2005",
#         "avg_lessthan50k": 6054.88,
#         "avg_fiftyTo75k": 11247.46,
#         "avg_seventy5To100k": 9474.19,
#         "avg_over100k": 6573.32
#     },
#     {
#         "year": "2006",
#         "avg_lessthan50k": 6342.41,
#         "avg_fiftyTo75k": 13227.94,
#         "avg_seventy5To100k": 9585.12,
#         "avg_over100k": 6902.19
#     },
#     {
#         "year": "2007",
#         "avg_lessthan50k": 6416.13,
#         "avg_fiftyTo75k": 12492.24,
#         "avg_seventy5To100k": 9173.38,
#         "avg_over100k": 6884.63
#     },
#     {
#         "year": "2008",
#         "avg_lessthan50k": 6624.36,
#         "avg_fiftyTo75k": 12965.04,
#         "avg_seventy5To100k": 9558.33,
#         "avg_over100k": 7151.5
#     },
#     {
#         "year": "2009",
#         "avg_lessthan50k": 6365.81,
#         "avg_fiftyTo75k": 11431.46,
#         "avg_seventy5To100k": 9025.14,
#         "avg_over100k": 6833.13
#     },
#     {
#         "year": "2010",
#         "avg_lessthan50k": 6987.33,
#         "avg_fiftyTo75k": 13038.42,
#         "avg_seventy5To100k": 9312.32,
#         "avg_over100k": 7489.95
#     },
#     {
#         "year": "2011",
#         "avg_lessthan50k": 7889.93,
#         "avg_fiftyTo75k": 13017.72,
#         "avg_seventy5To100k": 10948.53,
#         "avg_over100k": 8478.94
#     },
#     {
#         "year": "2012",
#         "avg_lessthan50k": 8280.04,
#         "avg_fiftyTo75k": 13301.74,
#         "avg_seventy5To100k": 10781.78,
#         "avg_over100k": 8882.9
#     },
#     {
#         "year": "2013",
#         "avg_lessthan50k": 9052.87,
#         "avg_fiftyTo75k": 13876.83,
#         "avg_seventy5To100k": 11383.34,
#         "avg_over100k": 9762.37
#     },
#     {
#         "year": "2014",
#         "avg_lessthan50k": 10335.68,
#         "avg_fiftyTo75k": 15595.56,
#         "avg_seventy5To100k": 12622.77,
#         "avg_over100k": 11215.79
#     },
#     {
#         "year": "2015",
#         "avg_lessthan50k": 12349.31,
#         "avg_fiftyTo75k": 16928.4,
#         "avg_seventy5To100k": 14379.79,
#         "avg_over100k": 13340.13
#     },
#     {
#         "year": "2016",
#         "avg_lessthan50k": 14025.79,
#         "avg_fiftyTo75k": 18535.86,
#         "avg_seventy5To100k": 15858.95,
#         "avg_over100k": 15192.16
#     },
#     {
#         "year": "2017",
#         "avg_lessthan50k": 16780.85,
#         "avg_fiftyTo75k": 19666.57,
#         "avg_seventy5To100k": 17064.04,
#         "avg_over100k": 17452.72
#     },
#     {
#         "year": "2018",
#         "avg_lessthan50k": 20244.89,
#         "avg_fiftyTo75k": 21464.43,
#         "avg_seventy5To100k": 19216.62,
#         "avg_over100k": 20338.77
#     },
#     {
#         "year": "2019",
#         "avg_lessthan50k": 23845.07,
#         "avg_fiftyTo75k": 22843.36,
#         "avg_seventy5To100k": 21035.91,
#         "avg_over100k": 23063.66
#     },
#     {
#         "year": "2020",
#         "avg_lessthan50k": 27566.61,
#         "avg_fiftyTo75k": 25281.74,
#         "avg_seventy5To100k": 24539.78,
#         "avg_over100k": 26544.66
#     },
#     {
#         "year": "2021",
#         "avg_lessthan50k": 31572.96,
#         "avg_fiftyTo75k": 28700.98,
#         "avg_seventy5To100k": 30058.5,
#         "avg_over100k": 30824.85
#     },
#     {
#         "year": "2022",
#         "avg_lessthan50k": 35146.17,
#         "avg_fiftyTo75k": 33428.65,
#         "avg_seventy5To100k": 35783.52,
#         "avg_over100k": 35067.57
#     },
#     {
#         "year": "2023",
#         "avg_lessthan50k": 36489.51,
#         "avg_fiftyTo75k": 37803.77,
#         "avg_seventy5To100k": 39657.53,
#         "avg_over100k": 37155.09
#     },
#     {
#         "year": "2024",
#         "avg_lessthan50k": 33276.53,
#         "avg_fiftyTo75k": 38554.85,
#         "avg_seventy5To100k": 35481.22,
#         "avg_over100k": 35137.87
#     },
#     {
#         "year": "2025",
#         "avg_lessthan50k": 15087.79,
#         "avg_fiftyTo75k": 15619.4,
#         "avg_seventy5To100k": 10490.53,
#         "avg_over100k": 15143.01
#     }
# ]

# %% [markdown]
# # Table for unique car make

# %%
# Create the unique_car_make_view
create_table("unique_car_make_names_table", "SELECT DISTINCT UPPER(SUBSTR(make, 1, 1)) || LOWER(SUBSTR(make, 2)) AS make FROM carbitrage_table WHERE make IS NOT NULL;")
# Out:
# Table unique_car_make_names_table created successfully.

# %% [markdown]
# # Table for unique car model

# %%
# Create the unique_car_make_view
create_table("unique_car_model_names_table", "SELECT DISTINCT UPPER(SUBSTR(model, 1, 1)) || LOWER(SUBSTR(model, 2)) AS model FROM carbitrage_table WHERE model IS NOT NULL;")
# Out:
# Table unique_car_model_names_table created successfully.

# %% [markdown]
# # Table - City Names

# %%
# Create the unique_car_location_view
create_table("unique_car_location_names_table", "SELECT DISTINCT UPPER(SUBSTR(location, 1, 1)) || LOWER(SUBSTR(location, 2)) AS location FROM carbitrage_table WHERE location IS NOT NULL;")
# Out:
# Table unique_car_location_names_table created successfully.

# %% [markdown]
# # Table - Car Title

# %%
# Create the unique_car_make_view
create_table("unique_car_title_names_table", "SELECT DISTINCT UPPER(SUBSTR(title, 1, 1)) || LOWER(SUBSTR(title, 2)) AS title FROM carbitrage_table WHERE title IS NOT NULL;")
# Out:
# Table unique_car_title_names_table created successfully.

# %% [markdown]
# # Table - State

# %%
# Create the unique_car_make_view
create_table("unique_state_table", "SELECT DISTINCT UPPER(SUBSTR(state, 1, 1)) || LOWER(SUBSTR(state, 2)) AS state FROM carbitrage_table WHERE state IS NOT NULL;")
# Out:
# Table unique_state_table created successfully.
